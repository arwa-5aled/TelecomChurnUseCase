# %%
import pandas as pd 
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head(10)
# Out:
#    customerID  gender  Senior_Citizen  Is_Married Dependents  tenure  \
# 0  7590-VHVEG  Female                0        Yes         No       1
# 1  5575-GNVDE    Male                0         No         No      34
# 2  3668-QPYBK    Male                0         No         No       2
# 3  7795-CFOCW    Male                0         No         No      45
# 4  9237-HQITU  Female                0         No         No       2
# 5  9305-CDSKC  Female                0         No         No       8
# 6  1452-KIOVK    Male                0         No        Yes      22
# 7  6713-OKOMC  Female                0         No         No      10
# 8  7892-POOKP  Female                0        Yes         No      28
# 9  6388-TABGU    Male                0         No        Yes      62
#
#   Phone_Service              Dual Internet_Service Online_Security  ...  \
# 0            No  No phone service              DSL              No  ...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'Senior_Citizen ', 'Is_Married', 'Dependents',
#        'tenure', 'Phone_Service', 'Dual', 'Internet_Service',
#        'Online_Security', 'Online_Backup', 'Device_Protection', 'Tech_Support',
#        'Streaming_TV', 'Streaming_Movies', 'Contract', 'Paperless_Billing',
#        'Payment_Method', 'Monthly_Charges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         7043 non-null   object
#  1   gender             7043 non-null   object
#  2   Senior_Citizen     7043 non-null   int64
#  3   Is_Married         7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   tenure             7043 non-null   int64
#  6   Phone_Service      7043 non-null   object
#  7   Dual               7043 non-null   object
#  8   Internet_Service   7043 non-null   object
#  9   Online_Security    7043 non-null   object
#  10  Online_Backup      7043 non-null   object
#  11  Device_Protection  7043 non-null   object
#  12  Tech_Support       7043 non-null   object
#  13  Streaming_TV       7043 non-null   object
#  14  Streaming_Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
# ...

# %%
msno.matrix(df)
plt.show()

# %%
def show_unique_values(df):
    for col in df.columns:
        unique_vals = df[col].unique()
        print(f"\nColumn: {col}")
        print(f"Number of unique values: {len(unique_vals)}")
        print(f"Unique values: {unique_vals[:15]}")  # show only first 15 to avoid clutter

# %%
show_unique_values(df)
# Out:
# Column: customerID
# Number of unique values: 7043
# Unique values: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' '7795-CFOCW' '9237-HQITU'
#  '9305-CDSKC' '1452-KIOVK' '6713-OKOMC' '7892-POOKP' '6388-TABGU'
#  '9763-GRSKD' '7469-LKBCI' '8091-TTVAX' '0280-XJGEX' '5129-JLPIS']
#
# Column: gender
# Number of unique values: 2
# Unique values: ['Female' 'Male']
#
# Column: Senior_Citizen
# Number of unique values: 2
# Unique values: [0 1]
#
# Column: Is_Married
# Number of unique values: 2
# Unique values: ['Yes' 'No']
#
# Column: Dependents
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: tenure
# Number of unique values: 73
# Unique values: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69]
#
# Column: Phone_Service
# Number of unique values: 2
# Unique values: ['No' 'Yes']
#
# Column: Dual
# Number of unique values: 3
# Unique values: ['No phone service' 'No' 'Yes']
#
# Column: Internet_Service
# Number of unique values: 3
# Unique values: ['DSL' 'Fiber optic' 'No']
#
# ...

# %%
df['tenure'].unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39])

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'Senior_Citizen ', 'Is_Married', 'Dependents',
#        'tenure', 'Phone_Service', 'Dual', 'Internet_Service',
#        'Online_Security', 'Online_Backup', 'Device_Protection', 'Tech_Support',
#        'Streaming_TV', 'Streaming_Movies', 'Contract', 'Paperless_Billing',
#        'Payment_Method', 'Monthly_Charges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df['Senior_Citizen '] = df['Senior_Citizen '].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         7043 non-null   object
#  1   gender             7043 non-null   object
#  2   Senior_Citizen     7043 non-null   object
#  3   Is_Married         7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   tenure             7043 non-null   int64
#  6   Phone_Service      7043 non-null   object
#  7   Dual               7043 non-null   object
#  8   Internet_Service   7043 non-null   object
#  9   Online_Security    7043 non-null   object
#  10  Online_Backup      7043 non-null   object
#  11  Device_Protection  7043 non-null   object
#  12  Tech_Support       7043 non-null   object
#  13  Streaming_TV       7043 non-null   object
#  14  Streaming_Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
# ...

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         7043 non-null   object
#  1   gender             7043 non-null   object
#  2   Senior_Citizen     7043 non-null   object
#  3   Is_Married         7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   tenure             7043 non-null   int64
#  6   Phone_Service      7043 non-null   object
#  7   Dual               7043 non-null   object
#  8   Internet_Service   7043 non-null   object
#  9   Online_Security    7043 non-null   object
#  10  Online_Backup      7043 non-null   object
#  11  Device_Protection  7043 non-null   object
#  12  Tech_Support       7043 non-null   object
#  13  Streaming_TV       7043 non-null   object
#  14  Streaming_Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
# ...

# %%
print("Missing in Total_Charges:", df['Total_Charges'].isnull().sum())
# Out:
# Missing in Total_Charges: 11

# %%
msno.matrix(df)
plt.show()

# %%
sns.scatterplot(x='Monthly_Charges', y='Total_Charges', data=df, alpha=0.5)
plt.title("Monthly Charges vs Total Charges")
plt.show()

# %%
corr = df[['Monthly_Charges','Total_Charges']].corr()
print(corr)
# Out:
#                  Monthly_Charges  Total_Charges
# Monthly_Charges         1.000000       0.651065
# Total_Charges           0.651065       1.000000

# %%
null_total = df[df['Total_Charges'].isnull()]

# %%
null_total[['Monthly_Charges', 'tenure', 'Total_Charges']]
# Out:
#       Monthly_Charges  tenure  Total_Charges
# 488             52.55       0            NaN
# 753             20.25       0            NaN
# 936             80.85       0            NaN
# 1082            25.75       0            NaN
# 1340            56.05       0            NaN
# 3331            19.85       0            NaN
# 3826            25.35       0            NaN
# 4380            20.00       0            NaN
# 5218            19.70       0            NaN
# 6670            73.35       0            NaN
# 6754            61.90       0            NaN

# %%
df['Total_Charges'] = df['Total_Charges'].fillna(0)

# %%
mask = (df['Dual'] == 'No phone service')
invalid_rows = df[mask & (df['Phone_Service'] != 'No')]
print(f"Number of inconsistent rows: {len(invalid_rows)}")
display(invalid_rows[['customerID', 'Phone_Service', 'Dual']])
# Out:
# Number of inconsistent rows: 0
# Empty DataFrame
# Columns: [customerID, Phone_Service, Dual]
# Index: []

# %%
internet_related = [
    'Online_Security','Online_Backup','Device_Protection',
    'Tech_Support','Streaming_TV','Streaming_Movies'
]

mask = df['Internet_Service'] == 'No'

for col in internet_related:
    inconsistent = df[mask & (df[col] != 'No internet service')]
    print(f"{col}: {len(inconsistent)} inconsistent rows")
    if not inconsistent.empty:
        display(inconsistent[['CustomerId','Internet_Service',col]])
# Out:
# Online_Security: 0 inconsistent rows
# Online_Backup: 0 inconsistent rows
# Device_Protection: 0 inconsistent rows
# Tech_Support: 0 inconsistent rows
# Streaming_TV: 0 inconsistent rows
# Streaming_Movies: 0 inconsistent rows

# %%
mask = (df['Dual'] == 'No phone service')
invalid_rows = df[mask & (df['Phone_Service'] != 'No')]
print(f"Number of inconsistent rows: {len(invalid_rows)}")
display(invalid_rows[['customerID', 'Phone_Service', 'Dual']])
# Out:
# Number of inconsistent rows: 0
# Empty DataFrame
# Columns: [customerID, Phone_Service, Dual]
# Index: []

# %%
df.describe()
# Out:
#             tenure  Monthly_Charges  Total_Charges
# count  7043.000000      7043.000000    7043.000000
# mean     32.371149        64.761692    2279.734304
# std      24.559481        30.090047    2266.794470
# min       0.000000        18.250000       0.000000
# 25%       9.000000        35.500000     398.550000
# 50%      29.000000        70.350000    1394.550000
# 75%      55.000000        89.850000    3786.600000
# max      72.000000       118.750000    8684.800000

# %%
sns.countplot(x='Churn', data=df, palette="Set2")
plt.title("Churn Distribution")
plt.show()
# Out:
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\1589110588.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette="Set2")

# %%
sns.countplot(x='Churn', data=df, palette="Set2")
plt.title("Churn Distribution")

total = len(df)
for p in plt.gca().patches:
    percentage = f'{100 * p.get_height() / total:.2f}%'
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='bottom', fontsize=10)

plt.show()
# Out:
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\40828102.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette="Set2")

# %%
def plot_cat_vs_target(df, feature, target='Churn'):
  
    ctab = pd.crosstab(df[feature], df[target], normalize='index') * 100
    display(ctab.round(2))   # show churn % table
    
  
    plt.figure(figsize=(6,4))
    sns.countplot(x=feature, hue=target, data=df, palette="Set2")
    plt.title(f"{feature} vs {target}")
    plt.xticks(rotation=45)
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerID         7043 non-null   object
#  1   gender             7043 non-null   object
#  2   Senior_Citizen     7043 non-null   object
#  3   Is_Married         7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   tenure             7043 non-null   int64
#  6   Phone_Service      7043 non-null   object
#  7   Dual               7043 non-null   object
#  8   Internet_Service   7043 non-null   object
#  9   Online_Security    7043 non-null   object
#  10  Online_Backup      7043 non-null   object
#  11  Device_Protection  7043 non-null   object
#  12  Tech_Support       7043 non-null   object
#  13  Streaming_TV       7043 non-null   object
#  14  Streaming_Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
# ...

# %%
categorical_features = [
    'gender','Senior_Citizen ','Is_Married','Dependents',
    'Phone_Service','Internet_Service','Online_Security','Online_Backup',
    'Device_Protection','Tech_Support','Streaming_TV','Streaming_Movies',
    'Contract','Paperless_Billing','Payment_Method'
]
for feature in categorical_features:
    plot_cat_vs_target(df, feature)
# Out:
# Churn      No    Yes
# gender
# Female  73.08  26.92
# Male    73.84  26.16
# Churn               No    Yes
# Senior_Citizen
# 0                76.39  23.61
# 1                58.32  41.68
# Churn          No    Yes
# Is_Married
# No          67.04  32.96
# Yes         80.34  19.66
# Churn          No    Yes
# Dependents
# No          68.72  31.28
# Yes         84.55  15.45
# Churn             No    Yes
# Phone_Service
# No             75.07  24.93
# Yes            73.29  26.71
# Churn                No    Yes
# Internet_Service
# DSL               81.04  18.96
# Fiber optic       58.11  41.89
# No                92.60   7.40
# Churn                   No    Yes
# Online_Security
# No                   58.23  41.77
# No internet service  92.60   7.40
# Yes                  85.39  14.61
# Churn                   No    Yes
# Online_Backup
# No                   60.07  39.93
# No internet service  92.60   7.40
# Yes                  78.47  21.53
# Churn                   No    Yes
# ...

# %%
def plot_churn_rate(df, feature, target='Churn'):
    churn_rate = df.groupby(feature)[target].apply(lambda x: (x=='Yes').mean()*100)
    churn_rate.plot(kind='bar', figsize=(6,4), color="tomato")
    plt.ylabel("Churn Rate (%)")
    plt.title(f"Churn Rate by {feature}")
    plt.xticks(rotation=45)
    plt.show()

for col in categorical_features:
    plot_churn_rate(df, col)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'Senior_Citizen ', 'Is_Married', 'Dependents',
#        'tenure', 'Phone_Service', 'Dual', 'Internet_Service',
#        'Online_Security', 'Online_Backup', 'Device_Protection', 'Tech_Support',
#        'Streaming_TV', 'Streaming_Movies', 'Contract', 'Paperless_Billing',
#        'Payment_Method', 'Monthly_Charges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df.groupby('Churn')[['tenure']].describe()
# Out:
#        tenure
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
df.groupby('Churn')[['Monthly_Charges']].describe()
# Out:
#       Monthly_Charges                                                    \
#                 count       mean        std    min    25%     50%   75%
# Churn
# No             5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4
# Yes            1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2
#
#
#           max
# Churn
# No     118.75
# Yes    118.35

# %%
df.groupby('Churn')[['Total_Charges']].describe()
# Out:
#       Total_Charges                                                    \
#               count         mean          std    min    25%       50%
# Churn
# No           5174.0  2549.911442  2329.954215   0.00  572.9  1679.525
# Yes          1869.0  1531.796094  1890.822994  18.85  134.5   703.550
#
#
#            75%      max
# Churn
# No     4262.85  8672.45
# Yes    2331.30  8684.80

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_features = ['tenure', 'Monthly_Charges', 'Total_Charges']

for col in num_features:
    plt.figure(figsize=(6,4))
    sns.histplot(data=df, x=col, hue='Churn', kde=True, bins=30)
    plt.title(f"Distribution of {col} by Churn")
    plt.show()

# %%
for col in num_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='Churn', y=col, data=df, palette="Set2")
    plt.title(f"{col} vs Churn")
    plt.show()
# Out:
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\7837973.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y=col, data=df, palette="Set2")
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\7837973.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y=col, data=df, palette="Set2")
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\7837973.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y=col, data=df, palette="Set2")

# %%
for col in ['tenure', 'Monthly_Charges', 'Total_Charges']:
    plt.figure(figsize=(6,4))
    sns.violinplot(x='Churn', y=col, data=df, split=True, inner="quartile")
    plt.title(f"{col} vs Churn")
    plt.show()

# %%
for col in ['tenure','Monthly_Charges','Total_Charges']:
    plt.figure(figsize=(6,4))
    sns.kdeplot(df[df['Churn']=="Yes"][col], label="Churn=Yes", shade=True)
    sns.kdeplot(df[df['Churn']=="No"][col], label="Churn=No", shade=True)
    plt.title(f"Density of {col} by Churn")
    plt.legend()
    plt.show()
# Out:
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\4062650205.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Churn']=="Yes"][col], label="Churn=Yes", shade=True)
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\4062650205.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Churn']=="No"][col], label="Churn=No", shade=True)
# C:\Users\EL RWAD\AppData\Local\Temp\ipykernel_4348\4062650205.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Churn']=="Yes"][col], label="Churn=Yes", shade=True)
# ...
